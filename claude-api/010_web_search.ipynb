# %%
import anthropic
import dotenv
print("Both installed!")

# Load env variables
from dotenv import load_dotenv

load_dotenv()
print("Env variables loaded!")

# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"
print("Client created!")
# Out:
# Both installed!
# Env variables loaded!
# Client created!

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type":"web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"]
}

# %%
messages = []
add_user_message(
    messages,
    """
    What is the best schedule to have swimming as a workout?
    """,
)
response = chat(messages)
response
# Out:
# Message(id='msg_013vY6qqYcxtjSpmjAzbqiJq', container=None, content=[TextBlock(citations=None, text='# Best Swimming Workout Schedule\n\n## Frequency Recommendations\n\n| Fitness Level | Sessions Per Week | Duration Per Session |\n|--------------|-------------------|----------------------|\n| Beginner | 2-3 days | 20-30 minutes |\n| Intermediate | 3-4 days | 30-45 minutes |\n| Advanced | 4-6 days | 45-60+ minutes |\n\n---\n\n## Sample Weekly Schedule\n\n### **Beginner Schedule**\n- **Monday** - Easy swim, focus on technique\n- **Wednesday** - Moderate effort, mix of strokes\n- **Friday** - Endurance building\n\n### **Intermediate Schedule**\n- **Monday** - Endurance swim\n- **Tuesday** - Rest or light activity\n- **Wednesday** - Interval training\n- **Thursday** - Rest\n- **Friday** - Technique + speed work\n- **Saturday** - Longer distance swim\n\n---\n\n## Key Tips for Scheduling\n\n- ✅ **Rest days matter** - muscles need recovery\n- ✅ **Morning swims** can boost metabolism for the day\n- ✅ **Consistency** beats intensity for long-term results\n- ✅ **Mix stroke styles** to work different muscles\n- ✅ **Warm up and cool down** every session\n\n---\n\n## Best Times to Swim\n- **Morning** - Energizes your day\n- **Lunch break** - Stress relief\n- **Evening** - Good for unwinding\n\nWould you like a more **specific plan** based on your fitness goal? 🏊', type='text')], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=24, output_tokens=359, server_tool_use=None, service_tier='standard'))
